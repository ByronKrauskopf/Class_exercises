# %%
# Import Dependencies
import pandas as pd

# %%
# Create a path to the csv and read it into a Pandas DataFrame
csv_path = "Resources/ted_talks.csv"
ted_df = pd.read_csv(csv_path)

ted_df.head()
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
# 2       124  New York Times columnist David Pogue takes aim...      1286
# 3       200  In an emotionally charged talk, MacArthur-winn...      1116
# 4       593  You've never seen data presented like this. Wi...      1190
#
#      event  languages   main_speaker  \
# 0  TED2006         60   Ken Robinson
# 1  TED2006         43        Al Gore
# 2  TED2006         26    David Pogue
# 3  TED2006         35  Majora Carter
# 4  TED2006         48   Hans Rosling
#
#                                             name  \
# 0      Ken Robinson: Do schools kill creativity?
# 1           Al Gore: Averting the climate crisis
# 2                  David Pogue: Simplicity sells
# 3             Majora Carter: Greening the ghetto
# 4  Hans Rosling: The best stats you've ever seen
#
#                              title     views
# 0      Do schools kill creativity?  47227110
# 1      Averting the climate crisis   3200520
# 2                 Simplicity sells   1636292
# 3              Greening the ghetto   1697550
# 4  The best stats you've ever seen  12005869

# %%
# Figure out the minimum and maximum views for a TED Talk
print(ted_df["views"].min())
print(ted_df["views"].max())
# Out:
# 50443
# 47227110

# %%
ted_df["views"].describe()
# Out:
# count    2.550000e+03
# mean     1.698297e+06
# std      2.498479e+06
# min      5.044300e+04
# 25%      7.557928e+05
# 50%      1.124524e+06
# 75%      1.700760e+06
# max      4.722711e+07
# Name: views, dtype: float64

# %%
# Create bins in which to place values based upon TED Talk views
bins = [0, 4000000, 8000000, 12000000, 16000000, 20000000, 24000000, 28000000, 32000000, 36000000, 40000000, 50000000]
# Create labels for these bins
group_labels = ["< 4 million", "4-8 million", "8-12 million", "12-16 million", "16-20 million", "20-24 million", "24-28 million",
               "28-32 million", "32-36 million", "36-40 million", ">40 million"]

# %%
# Slice the data and place it into bins
pd.cut(ted_df["views"], bins)
# Out:
# 0       (40000000, 50000000]
# 1               (0, 4000000]
# 2               (0, 4000000]
# 3               (0, 4000000]
# 4       (12000000, 16000000]
#                 ...
# 2545            (0, 4000000]
# 2546            (0, 4000000]
# 2547            (0, 4000000]
# 2548            (0, 4000000]
# 2549            (0, 4000000]
# Name: views, Length: 2550, dtype: category
# Categories (11, interval[int64]): [(0, 4000000] < (4000000, 8000000] < (8000000, 12000000] < (12000000, 16000000] ... (28000000, 32000000] < (32000000, 36000000] < (36000000, 40000000] < (40000000, 50000000]]

# %%
# Place the data series into a new column inside of the DataFrame
ted_df["View Group"] = pd.cut(ted_df["views"], bins, labels=group_labels)
ted_df
# Out:
#       comments                                        description  duration  \
# 0         4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1          265  With the same humor and humanity he exuded in ...       977
# 2          124  New York Times columnist David Pogue takes aim...      1286
# 3          200  In an emotionally charged talk, MacArthur-winn...      1116
# 4          593  You've never seen data presented like this. Wi...      1190
# ...        ...                                                ...       ...
# 2545        17  Between 2008 and 2016, the United States depor...       476
# 2546         6  How can you study Mars without a spaceship? He...       290
# 2547        10  Science fiction visions of the future show us ...       651
# 2548        32  In an unmissable talk about race and politics ...      1100
# 2549         8  With more than half of the world population li...       519
#
#              event  languages         main_speaker  \
# 0          TED2006         60         Ken Robinson
# 1          TED2006         43              Al Gore
# 2          TED2006         26          David Pogue
# 3          TED2006         35        Majora Carter
# 4          TED2006         48         Hans Rosling
# ...            ...        ...                  ...
# 2545       TED2017          4     Duarte Geraldino
# 2546       TED2017          3  Armando Azua-Bustos
# 2547       TED2017          1       Radhika Nagpal
# 2548  TEDxMileHigh          1     Theo E.J. Wilson
# 2549       TED2017          1    Karoliina Korppoo
#
#                                                    name  \
# 0             Ken Robinson: Do schools kill creativity?
# 1                  Al Gore: Averting the climate crisis
# 2                         David Pogue: Simplicity sells
# 3                    Majora Carter: Greening the ghetto
# 4         Hans Rosling: The best stats you've ever seen
# ...                                                 ...
# 2545  Duarte Geraldino: What we're missing in the de...
# 2546  Armando Azua-Bustos: The most Martian place on...
# 2547  Radhika Nagpal: What intelligent machines can ...
# 2548  Theo E.J. Wilson: A black man goes undercover ...
# 2549  Karoliina Korppoo: How a video game might help...
#
#                                                   title     views  \
# 0                           Do schools kill creativity?  47227110
# 1                           Averting the climate crisis   3200520
# 2                                      Simplicity sells   1636292
# 3                                   Greening the ghetto   1697550
# 4                       The best stats you've ever seen  12005869
# ...                                                 ...       ...
# 2545  What we're missing in the debate about immigra...    450430
# 2546                    The most Martian place on Earth    417470
# 2547  What intelligent machines can learn from a sch...    375647
# 2548       A black man goes undercover in the alt-right    419309
# 2549  How a video game might help us build better ci...    391721
#
#          View Group
# 0       >40 million
# 1       < 4 million
# 2       < 4 million
# 3       < 4 million
# 4     12-16 million
# ...             ...
# 2545    < 4 million
# 2546    < 4 million
# 2547    < 4 million
# 2548    < 4 million
# 2549    < 4 million
#
# [2550 rows x 10 columns]

# %%
# Create a GroupBy object based upon "View Group"
ted_viewers = ted_df.groupby(ted_df["View Group"])

# %%
# Find how many rows fall into each bin
ted_viewers["name"].count()
# Out:
# View Group
# < 4 million      2383
# 4-8 million       114
# 8-12 million       26
# 12-16 million      11
# 16-20 million       7
# 20-24 million       5
# 24-28 million       0
# 28-32 million       1
# 32-36 million       1
# 36-40 million       0
# >40 million         2
# Name: name, dtype: int64

# %%
# Get the average of each column within the GroupBy object
ted_viewers["comments", "duration", "languages"].mean()
# Out:
# C:\Users\Byron\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#                   comments     duration  languages
# View Group
# < 4 million     163.496853   821.427612  26.549727
# 4-8 million     476.333333   900.850877  37.035088
# 8-12 million    594.807692   835.692308  38.653846
# 12-16 million   708.000000   917.181818  42.545455
# 16-20 million   895.142857   900.428571  43.000000
# 20-24 million   870.000000   918.600000  42.000000
# 24-28 million          NaN          NaN        NaN
# 28-32 million  1927.000000  1219.000000  52.000000
# 32-36 million  1930.000000  1084.000000  45.000000
# 36-40 million          NaN          NaN        NaN
# >40 million    3421.500000  1213.000000  55.500000

# %%
ted_viewers.describe()
# Out:
#               comments                                                     \
#                  count         mean          std     min      25%     50%
# View Group
# < 4 million     2383.0   163.496853   198.599276     2.0    60.00   109.0
# 4-8 million      114.0   476.333333   630.681871    46.0   230.25   355.5
# 8-12 million      26.0   594.807692   368.200925   129.0   323.25   567.0
# 12-16 million     11.0   708.000000   402.421918   285.0   432.00   659.0
# 16-20 million      7.0   895.142857   306.816682   527.0   657.50   846.0
# 20-24 million      5.0   870.000000  1138.006810   150.0   297.00   354.0
# 24-28 million      0.0          NaN          NaN     NaN      NaN     NaN
# 28-32 million      1.0  1927.000000          NaN  1927.0  1927.00  1927.0
# 32-36 million      1.0  1930.000000          NaN  1930.0  1930.00  1930.0
# 36-40 million      0.0          NaN          NaN     NaN      NaN     NaN
# >40 million        2.0  3421.500000  1600.182646  2290.0  2855.75  3421.5
#
#                                duration               ... languages        \
#                    75%     max    count         mean  ...       75%   max
# View Group                                            ...
# < 4 million     201.00  3356.0   2383.0   821.427612  ...     32.00  69.0
# 4-8 million     540.00  6404.0    114.0   900.850877  ...     40.75  65.0
# 8-12 million    760.00  1627.0     26.0   835.692308  ...     42.00  72.0
# 12-16 million   831.50  1604.0     11.0   917.181818  ...     47.50  49.0
# 16-20 million  1124.50  1329.0      7.0   900.428571  ...     44.00  46.0
# 20-24 million   672.00  2877.0      5.0   918.600000  ...     45.00  49.0
# 24-28 million      NaN     NaN      0.0          NaN  ...       NaN   NaN
# 28-32 million  1927.00  1927.0      1.0  1219.000000  ...     52.00  52.0
# 32-36 million  1930.00  1930.0      1.0  1084.000000  ...     45.00  45.0
# 36-40 million      NaN     NaN      0.0          NaN  ...       NaN   NaN
# >40 million    3987.25  4553.0      2.0  1213.000000  ...     57.75  60.0
#
#                 views                                                       \
#                 count          mean           std         min          25%
# View Group
# < 4 million    2383.0  1.239538e+06  7.350972e+05     50443.0    733694.00
# 4-8 million     114.0  5.253622e+06  1.117892e+06   4016531.0   4375387.75
# 8-12 million     26.0  9.276625e+06  9.249267e+05   8033595.0   8663852.50
# 12-16 million    11.0  1.387624e+07  1.219687e+06  12005869.0  13226909.50
# 16-20 million     7.0  1.743115e+07  1.404437e+06  16097077.0  16405827.00
# 20-24 million     5.0  2.124355e+07  7.214832e+05  20475972.0  20685401.00
# 24-28 million     0.0           NaN           NaN         NaN          NaN
# 28-32 million     1.0  3.116815e+07           NaN  31168150.0  31168150.00
# 32-36 million     1.0  3.430943e+07           NaN  34309432.0  34309432.00
# 36-40 million     0.0           NaN           NaN         NaN          NaN
# >40 million       2.0  4.519126e+07  2.879130e+06  43155405.0  44173331.25
#
#
#                       50%          75%         max
# View Group
# < 4 million     1073549.0   1541201.00   3982352.0
# 4-8 million     4806318.0   6122079.50   7988894.0
# 8-12 million    9085206.5   9938934.00  11443190.0
# 12-16 million  13926113.0  14717353.50  15601385.0
# 16-20 million  16861578.0  18230129.00  19787465.0
# 20-24 million  21190883.0  21594632.00  22270883.0
# 24-28 million         NaN          NaN         NaN
# 28-32 million  31168150.0  31168150.00  31168150.0
# 32-36 million  34309432.0  34309432.00  34309432.0
# 36-40 million         NaN          NaN         NaN
# >40 million    45191257.5  46209183.75  47227110.0
#
# [11 rows x 32 columns]
